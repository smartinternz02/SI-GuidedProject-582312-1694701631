# %% [markdown]
# # Assignment 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
df=pd.read_csv('/content/car_crashes.csv')

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.distplot(df.speeding)
# Out:
# <ipython-input-6-a1fcd64398a6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.speeding)
# <Axes: xlabel='speeding', ylabel='Density'>

# %% [markdown]
# Inference: This graph shows the univariate analysis of the speed dataset.

# %%
sns.jointplot(x='alcohol',y='not_distracted',data=df)

# %% [markdown]
# Inference: This graph shows the comparision between not_distractd component and the alcohol component.

# %%
sns.pairplot(df)

# %% [markdown]
# Inference:This graph shows the multivariate analysis between all the differnt datasets in this car crash dataframe.

# %%
df.isnull().any()
# Out:
# total             False
# speeding          False
# alcohol           False
# not_distracted    False
# no_previous       False
# ins_premium       False
# ins_losses        False
# abbrev            False
# dtype: bool

# %% [markdown]
# Conclusion: In the dataset there are no null values.
